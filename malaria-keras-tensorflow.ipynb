# %% [markdown]
# # Malaria: Parasite detection using ensemble learning in Keras and tensorflow

# %% [markdown]
# import/intall the required libraries: tensorflow, keras, sklearn, cv2, matplotlib, statistics
#
# !pip3 install keras tensorflow sklearn matplotlib opencv-python pandas

# %% [markdown]
# Dataset: https://www.tensorflow.org/datasets/catalog/malaria

# %%
import os
import glob
import threading
import statistics
import numpy as np
import pandas as pd
from concurrent import futures

# %%
# note: sklearn has been depreceated. plan accordantly but it is still running as written below
# More information is available at https://github.com/scikit-learn/sklearn-pypi-package

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score, precision_score, recall_score, classification_report

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset
# File names are obtained using the glob module

# %%
#select a random number of images
#check each class to be at least 50/50

infected = '/kaggle/input/malaria-cell-images/cell_images/Parasitized'
healthy = '/kaggle/input/malaria-cell-images/cell_images/Uninfected'

infected_files = glob.glob(infected+'/*.png')
healthy_files = glob.glob(healthy+'/*.png')

files_df = pd.DataFrame({
    'img': infected_files + healthy_files,
    'malaria': [1] * len(infected_files) + [0] * len(healthy_files)
})

files_df = files_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Just to reduce complexity
files_df = files_df.iloc[0:2000, :]
files_df['malaria'].value_counts()
# Out:
# malaria
# 1    1030
# 0     970
# Name: count, dtype: int64

# %% [markdown]
# # Create the datasets by transforming the images into arrays

# %%
#binary images | convert them into numbers
#pass them into the machine learning pipeline
#using cv2 library to read and resize the images
#get_data() function
#split the dataset into 80:20 train test split
#matplotlib.imshow() function to plot image from 3-d arrays

img_length, img_width = 50, 50


def get_data(data_files):
    data = []
    for img in data_files:
        print(img)
        img = cv2.imread(img)
        img = cv2.resize(img, dsize=(img_length, img_width),
                         interpolation=cv2.INTER_CUBIC)
        img = np.array(img)
        data += [img]
    return np.array(data)

X = files_df['img'].values
y = files_df['malaria'].values

X_converted = get_data(X)/255.0

train_data, val_data, train_labels, val_labels = train_test_split(
    X_converted, y, test_size=0.2, random_state=42)

# Check images

plt.figure(figsize=(8, 8))
plt.imshow(train_data[0])
plt.title('{}'.format(train_labels[0]))
plt.xticks([])
plt.yticks([])
plt.savefig('sample')
# Out:
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C98P59ThinF_IMG_20150917_154452_cell_203.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C189P150ThinF_IMG_20151203_141004_cell_72.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C210ThinF_IMG_20151029_162834_cell_153.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C215ThinF_IMG_20151106_133116_cell_196.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_148.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C232ThinF_IMG_20151112_154719_cell_115.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C132P93ThinF_IMG_20151004_151811_cell_155.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C182P143NThinF_IMG_20151201_172759_cell_45.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C133P94ThinF_IMG_20151004_155518_cell_99.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C59P20thinF_IMG_20150803_113139_cell_6.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_171.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C132P93ThinF_IMG_20151004_151701_cell_138.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C215ThinF_IMG_20151106_133247_cell_86.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C204ThinF_IMG_20151029_112231_cell_203.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C146P107ThinF_IMG_20151018_135846_cell_71.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C87P48ThinF_IMG_20150820_132642_cell_171.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C116P77ThinF_IMG_20150930_172112_cell_104.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C71P32_ThinF_IMG_20150813_162146_cell_217.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C99P60ThinF_IMG_20150918_142128_cell_119.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C154P115ThinF_IMG_20151115_141837_cell_205.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/C174P135NThinF_IMG_20151127_135512_cell_188.png
# /kaggle/input/malaria-cell-images/cell_images/Uninfected/C202ThinF_IMG_20151015_152333_cell_45.png
# /kaggle/input/malaria-cell-images/cell_images/Parasitized/
cell_images/Parasitized/C99P60ThinF_IMG_20150918_141001_cell_130.png

# %% [markdown]
# # Convolutional neural network (CNN)

# %% [markdown]
# #predicting presence or absence of maleria in cell images
# #adam optimizer used with learning_rate = 0.001
#
# import tensorflow as tf
# from keras.optimizers import SGD, Adam
# from keras.layers import Conv2D, Activation, Dense, MaxPooling2D, Flatten, Dropout
# from keras.models import Sequential
#
# model = Sequential()
# model.add(Conv2D(16, (3, 3), activation='relu',
#                  input_shape=(img_length, img_width, 3)))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Conv2D(16, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Conv2D(32, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Flatten())
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(1, activation='sigmoid'))
# model.summary()
#
# adam = Adam(learning_rate=0.001)
#
# model.compile(optimizer=adam,
#               loss='binary_crossentropy',
#               metrics=['accuracy'])

# %%
import tensorflow as tf
from keras.optimizers import Adam
from keras.layers import Input, Conv2D, Activation, Dense, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential

# Define input shape
input_shape = (img_length, img_width, 3)

# Create a sequential model
model = Sequential()

# Add the input layer with Input(shape)
model.add(Input(shape=input_shape))

# Add convolutional layers
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output
model.add(Flatten())

# Add fully connected layers
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Print model summary
model.summary()

# Compile the model
adam = Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 2024-02-29 03:22:04.573806: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 03:22:04.573958: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 03:22:04.759566: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 22, 22, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 11, 11, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 9, 9, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        16,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,857 (93.19 KB)
#  Trainable params: 23,857 (93.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train and Test the CNN

# %%
#call the model.fit in 25 epochs
#perform predictions
#measure prediction accuracy using classification
#Epoch 1/20
#25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8807 - loss: 0.2994 - val_accuracy: 0.8775 - val_loss: 0.2843
#Epoch 2/20


history = model.fit(x=train_data, y=train_labels, batch_size=64, epochs=20,
                    verbose=1, shuffle=True, validation_data=(val_data, val_labels))

# Predict probabilities for each class
y_probabilities = model.predict(val_data)

# Convert probabilities to binary predictions
y_predicted = (y_probabilities > 0.5).astype(int)

# y_predicted = model.predict_classes(val_data)

# accuracy = (true positives + true negatives) / (positives + negatives)
print('Accuracy: ', accuracy_score(val_labels, y_predicted))
# precision = true positives / (true positives + false positives)
print('Precision: ', precision_score(val_labels, y_predicted))
# recall = true positives / (true positives + false negatives)
print('Recall: ', recall_score(val_labels, y_predicted))
# f1 = 2 * (precision * recall) / (precision + recall)
print('f1: ', f1_score(val_labels, y_predicted))

print(classification_report(val_labels, y_predicted))

plt.subplot(211)
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
#predict how close we are from the actual values
# plot accuracy during training
plt.subplot(212)
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.savefig('accuracy_loss')
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.5053 - loss: 0.6979 - val_accuracy: 0.5450 - val_loss: 0.6891
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.5398 - loss: 0.6876 - val_accuracy: 0.4900 - val_loss: 0.6924
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.5540 - loss: 0.6819 - val_accuracy: 0.5750 - val_loss: 0.6742
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.5986 - loss: 0.6697 - val_accuracy: 0.6100 - val_loss: 0.6694
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.6155 - loss: 0.6599 - val_accuracy: 0.6600 - val_loss: 0.6111
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.6418 - loss: 0.6399 - val_accuracy: 0.6950 - val_loss: 0.6098
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7061 - loss: 0.6066 - val_accuracy: 0.6900 - val_loss: 0.6058
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.6927 - loss: 0.6002 - val_accuracy: 0.6000 - val_loss: 0.6507
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6416 - loss: 0.6308 - val_accuracy: 0.7350 - val_loss: 0.5714
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.7353 - loss: 0.5642 - val_accuracy: 0.7025 - val_loss: 0.5674
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7350 - loss: 0.5565 - val_accuracy: 0.7550 - val_loss: 0.5438
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7614 - loss: 0.5264 - val_accuracy: 0.7875 - val_loss: 0.4905
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.7872 - loss: 0.4789 - val_accuracy: 0.8150 - val_loss: 0.4487
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7924 - loss: 0.4577 - val_accuracy: 0.8375 - val_loss: 0.4088
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.8159 - loss: 0.4205 - val_accuracy: 0.8500 - val_loss: 0.3493
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8632 - loss: 0.3459 - val_accuracy: 0.8700 - val_loss: 0.3144
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.8836 - loss: 0.3115 - val_accuracy: 0.9050 - val_loss: 0.2760
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.8874 - loss: 0.3137 - val_accuracy: 0.9150 - val_loss: 0.2559
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9089 - loss: 0.2502 - val_accuracy: 0.9200 - val_loss: 0.2403
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9088 - loss: 0.2429 - val_accuracy: 0.9175 - val_loss: 0.2219
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Accuracy:  0.9175
# Precision:  0.9581151832460733
# Recall:  0.8798076923076923
# f1:  0.9172932330827067
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       192
#            1       0.96      0.88      0.92       208
#
#     accuracy                           0.92       400
#    macro avg       0.92      0.92      0.92       400
# weighted avg       0.92      0.92      0.92       400

# %% [markdown]
# # Create the CNN models ensemble

# %%
#Input(shape) object as the first layer in the model 
from keras.layers import Input

input_shape = (img_length, img_width, 3)  # Define input shape outside the loop

models = {}  # Create a dictionary to store models

for j in range(2, 4):
    newmodel = Sequential()
    newmodel.add(Input(shape=input_shape))  # Use Input layer as the first layer
    newmodel.add(Conv2D(j*16, (3, 3), activation='relu'))
    newmodel.add(MaxPooling2D(pool_size=(2, 2)))
    newmodel.add(Conv2D(j*16, (3, 3), activation='relu'))
    newmodel.add(MaxPooling2D(pool_size=(2, 2)))
    newmodel.add(Conv2D(j*32, (3, 3), activation='relu'))
    newmodel.add(MaxPooling2D(pool_size=(2, 2)))
    newmodel.add(Flatten())
    newmodel.add(Dense(j*32, activation='relu'))
    newmodel.add(Dropout(0.5))
    newmodel.add(Dense(1, activation='sigmoid'))

    newmodel.compile(optimizer=adam,
                     loss='binary_crossentropy',
                     metrics=['accuracy'])
    newmodel.summary()
    models[j] = newmodel
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 48, 48, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 22, 22, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 11, 11, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 9, 9, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 142,021 (554.77 KB)
#  Trainable params: 94,305 (368.38 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 47,716 (186.39 KB)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 48, 48, 48)     │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 24, 24, 48)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 22, 22, 48)     │        20,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 11, 11, 48)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 9, 9, 96)       │        41,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1536)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 96)             │       147,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            97 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 259,061 (1011.96 KB)
#  Trainable params: 211,345 (825.57 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 47,716 (186.39 KB)

# %% [markdown]
# # Fit the models in the ensemble and perform the prediction

# %%
for j in models:
    adam = Adam(learning_rate=0.001)  # Recreate optimizer for each model
    models[j].compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
    models[j].fit(x=train_data, y=train_labels, batch_size=64, epochs=25,
                  verbose=1, shuffle=True, validation_data=(val_data, val_labels))
# Out:
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.4887 - loss: 0.6978 - val_accuracy: 0.5650 - val_loss: 0.6826
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5642 - loss: 0.6836 - val_accuracy: 0.6025 - val_loss: 0.6804
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.5935 - loss: 0.6739 - val_accuracy: 0.5975 - val_loss: 0.6823
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.6067 - loss: 0.6643 - val_accuracy: 0.5425 - val_loss: 0.6917
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.6104 - loss: 0.6617 - val_accuracy: 0.6600 - val_loss: 0.6299
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.6378 - loss: 0.6429 - val_accuracy: 0.6800 - val_loss: 0.6108
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.6673 - loss: 0.6086 - val_accuracy: 0.7350 - val_loss: 0.5642
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7342 - loss: 0.5498 - val_accuracy: 0.7850 - val_loss: 0.5261
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7628 - loss: 0.5413 - val_accuracy: 0.7900 - val_loss: 0.4856
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7922 - loss: 0.4824 - val_accuracy: 0.8200 - val_loss: 0.4458
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8280 - loss: 0.4342 - val_accuracy: 0.8075 - val_loss: 0.4404
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8464 - loss: 0.4098 - val_accuracy: 0.8225 - val_loss: 0.3822
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.8940 - loss: 0.3309 - val_accuracy: 0.8600 - val_loss: 0.3202
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.8681 - loss: 0.3268 - val_accuracy: 0.9050 - val_loss: 0.2733
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.9078 - loss: 0.2629 - val_accuracy: 0.9050 - val_loss: 0.2371
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8996 - loss: 0.2341 - val_accuracy: 0.9150 - val_loss: 0.2304
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.9126 - loss: 0.2288 - val_accuracy: 0.9150 - val_loss: 0.2127
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.9111 - loss: 0.2345 - val_accuracy: 0.9250 - val_loss: 0.1954
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9338 - loss: 0.1765 - val_accuracy: 0.9150 - val_loss: 0.2200
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.9372 - loss: 0.1772 - val_accuracy: 0.9000 - val_loss: 0.2217
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.9361 - loss: 0.1576 - val_accuracy: 0.9200 - val_loss: 0.1930
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.9409 - loss: 0.1533 - val_accuracy: 0.8950 - val_loss: 0.2419
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9502 - loss: 0.1314 - val_accuracy: 0.9125 - val_loss: 0.2260
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9656 - loss: 0.1043 - val_accuracy: 0.9225 - val_loss: 0.2064
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9609 - loss: 0.1139 - val_accuracy: 0.9325 - val_loss: 0.2131
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.5278 - loss: 0.6947 - val_accuracy: 0.5800 - val_loss: 0.6857
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.5806 - loss: 0.6740 - val_accuracy: 0.6275 - val_loss: 0.6402
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.6498 - loss: 0.6285 - val_accuracy: 0.6300 - val_loss: 0.6463
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.6740 - loss: 0.6192 - val_accuracy: 0.6750 - val_loss: 0.5982
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.7247 - loss: 0.5756 - val_accuracy: 0.7500 - val_loss: 0.5532
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.7384 - loss: 0.5305 - val_accuracy: 0.8000 - val_loss: 0.4775
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.8165 - loss: 0.4467 - val_accuracy: 0.8350 - val_loss: 0.4168
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8403 - loss: 0.4036 - val_accuracy: 0.8625 - val_loss: 0.3438
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8780 - loss: 0.3153 - val_accuracy: 0.9075 - val_loss: 0.2604
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8950 - loss: 0.2621 - val_accuracy: 0.9175 - val_loss: 0.2410
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.8981 - loss: 0.2563 - val_accuracy: 0.9050 - val_loss: 0.2330
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.9086 - loss: 0.2352 - val_accuracy: 0.9050 - val_loss: 0.2352
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.9243 - loss: 0.2034 - val_accuracy: 0.9150 - val_loss: 0.2092
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.9397 - loss: 0.1824 - val_accuracy: 0.9250 - val_loss: 0.1935
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9457 - loss: 0.1464 - val_accuracy: 0.9225 - val_loss: 0.1860
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.9477 - loss: 0.1517 - val_accuracy: 0.9150 - val_loss: 0.1792
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.9586 - loss: 0.1178 - val_accuracy: 0.9250 - val_loss: 0.2012
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.9547 - loss: 0.1263 - val_accuracy: 0.9225 - val_loss: 0.2096
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.9567 - loss: 0.1111 - val_accuracy: 0.9200 - val_loss: 0.1994
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9686 - loss: 0.0872 - val_accuracy: 0.9275 - val_loss: 0.2075
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.9756 - loss: 0.0752 - val_accuracy: 0.9150 - val_loss: 0.2055
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.9765 - loss: 0.0700 - val_accuracy: 0.9225 - val_loss: 0.1966
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.9847 - loss: 0.0483 - val_accuracy: 0.9225 - val_loss: 0.2151
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9842 - loss: 0.0454 - val_accuracy: 0.9300 - val_loss: 0.2048
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9872 - loss: 0.0417 - val_accuracy: 0.9250 - val_loss: 0.2114

# %% [markdown]
# #fit each of the model using the same datasets
# for j in models:
#     models[j].fit(x=train_data, y=train_labels, batch_size=64, epochs=25,
#                   verbose=1, shuffle=True, validation_data=(val_data, val_labels))

# %%
#generate the predictcions and add them into an array predictions_hard
predictions_hard = []

for j in models:
    predictions = models[j].predict(val_data)
    predictions_binary = (predictions > 0.5).astype(int)
    predictions_hard.append(predictions_binary)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# # Apply hard voting to the ensemble

# %%
#mean function to get the class that was predicted more frequently or repeated the most
#we havve only 1's and 0's, it will pick the value that was repeated most frequently
voting_hard = []
for i in range(0, len(val_data)):
    voting_hard += [statistics.mode(
        [predictions_hard[0][i][0], predictions_hard[1][i][0]])]

print(classification_report(val_labels, voting_hard))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       192
#            1       0.96      0.91      0.93       208
#
#     accuracy                           0.93       400
#    macro avg       0.93      0.93      0.93       400
# weighted avg       0.93      0.93      0.93       400
